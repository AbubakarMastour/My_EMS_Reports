# %% [markdown]
# # Sage Report Three:

# %% [markdown]
# ## Frobenius coin problem
# We need to calculate the amount of money that we can make it from the two integers

# %% [markdown]
# If $a = 2$ and $b = 3$

# %% [markdown]
# if we need to calculate the Frobenius coin problem we need to consider this formula: $n = ax + by$ and this equation is called Linear Diophantine Equation, so we have to put all the posible number in this form

# %% [markdown]
# let us try to put a theorm for the above equation
# If $(x 0 , y 0 )$ is a solution of $ax + by = n$ , then all
# solutions are given by ${(x, y ) : x = x 0 + bt, y = y 0 − at, t ∈ Z}$
#
# let us proof that:
#
# $a(x 0 + bt) + b(y 0 − at) = ax 0 + abt + by 0 − bat = ax 0 + by 0$ and this is equal to $n$
#
# The largest integer that cannot be represented as a nonnegative
# linear combination of a and b is
#
# $g (a, b) = ab − a − b = (a − 1 )(b − 1 ) − 1.$
#
# **Credit:** Derek Orr.2017,The Frobenius Coin Problem A Geometric Proof for Two Variables,University of Pittsburgh.

# %% [markdown]
# and also if I consider the code of my colluage **Wandilie** and put some fingerprint on it I will get:

# %%
# first we need to define the number that we begin with it
beg_num =  1

# the we gonna use input function to ask the user to inter the value of a and b
a_value =  int(input("Enter the value of a: "))
b_vale =  int(input("Enter the value of b: "))

# we set our while loop for n less that or equal 100 to be stop point
while beg_num<= 100:
    
    # then we need an empty list to store our value of x and y on it
    List = []
    
    # then we set for loop to generate the value of x in range 101 because python starts from count 0
    for x in range(1,101):
        
    # then we set for loop to generate the value of y in range 101 because python starts from count 0
        for y in range(1,101):
            
        # then we gonna define our equation that contain the a, b, x and y and equal it to n
            if (a_value*x + b_vale*y)==beg_num :
               # then we define variable to store our x and y on it 
                x_y_values = (x,y)
                # and then we gonna add the previous values to the our list
                List.append(x_y_values)
                # and finally we can print our results
                print("the combination Values are ", beg_num,List)
                 
    beg_num += 1
#print(trial_dict)
# Out:
# Enter the value of a: 2
# Enter the value of b: 3
# the combination Values are  5 [(1, 1)]
# the combination Values are  7 [(2, 1)]
# the combination Values are  8 [(1, 2)]
# the combination Values are  9 [(3, 1)]
# the combination Values are  10 [(2, 2)]
# the combination Values are  11 [(1, 3)]
# the combination Values are  11 [(1, 3), (4, 1)]
# the combination Values are  12 [(3, 2)]
# the combination Values are  13 [(2, 3)]
# the combination Values are  13 [(2, 3), (5, 1)]
# the combination Values are  14 [(1, 4)]
# the combination Values are  14 [(1, 4), (4, 2)]
# the combination Values are  15 [(3, 3)]
# the combination Values are  15 [(3, 3), (6, 1)]
# the combination Values are  16 [(2, 4)]
# the combination Values are  16 [(2, 4), (5, 2)]
# the combination Values are  17 [(1, 5)]
# the combination Values are  17 [(1, 5), (4, 3)]
# the combination Values are  17 [(1, 5), (4, 3), (7, 1)]
# the combination Values are  18 [(3, 4)]
# ...

# %% [markdown]
# As we can see from the code we can enter any number for the a and b and the code can return to us the result and give us all possible values for x and y
